# %% [markdown]
# <a href="https://colab.research.google.com/github/raidenshogen/Coffe_project/blob/main/Kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import KMeans
import  matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import datasets
import DBSCAN as DBSCAN

# %%
iris=datasets.load_iris();
df=pd.DataFrame(iris.data);
df.columns=['sepal_length','sepal_width','petal_length','petal_width'];
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
tab=[];
for i in range(1,10):
    kmeans=KMeans(n_clusters=i);
    kmeans.fit(df);
    tab.append(kmeans.inertia_);
plt.plot(range(1,10),tab);
plt.title("la methode LBOW")
plt.xlabel("nombre de cluster")
plt.ylabel("inertie intra-classe")
plt.show();

# %%
kmeans=KMeans(n_clusters=3);
kmeans.fit(df)

colormap=np.array(['red','green','blue']);
plt.scatter(df.sepal_length,df.sepal_width,c=colormap[kmeans.labels_],s=20);
plt.show();

# %%
plt.scatter(df.sepal_length,df.sepal_width,c=colormap[iris.target],s=20);
plt.show();
